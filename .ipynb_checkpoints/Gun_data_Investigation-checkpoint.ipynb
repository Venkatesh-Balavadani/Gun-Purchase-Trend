# %%
#importing required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import calendar
# %matplotlib inline

# %%
#reading the csv files
gun_dataFrame = pd.read_csv('gun_data.csv')

# %%
census_dataFrame = pd.read_csv('U.S. Census Data.csv')

# %%
census_dataFrame.head(4)
# Out:
#                                                 Fact Fact Note    Alabama  \
# 0       Population estimates, July 1, 2016,  (V2016)       NaN  48,63,300
# 1  Population estimates base, April 1, 2010,  (V2...       NaN  47,80,131
# 2  Population, percent change - April 1, 2010 (es...       NaN      0.017
# 3                  Population, Census, April 1, 2010       NaN  47,79,736
#
#      Alaska    Arizona   Arkansas   California   Colorado Connecticut  \
# 0  7,41,894  69,31,071  29,88,248  3,92,50,017  55,40,545   35,76,452
# 1  7,10,249  63,92,301  29,16,025  3,72,54,522  50,29,324   35,74,114
# 2     0.045      0.084      0.025        0.054      0.102       0.001
# 3  7,10,231  63,92,017  29,15,918  3,72,53,956  50,29,196   35,74,097
#
#    Delaware  ... South Dakota    Tennessee        Texas       Utah   Vermont  \
# 0  9,52,065  ...   865454.000  6651194.000  2,78,62,596  30,51,217  6,24,594
# 1  8,97,936  ...   814195.000  6346298.000  2,51,46,100  27,63,888  6,25,741
# ...

# %%
#getting the required data from the dataset
census_dataFrame = census_dataFrame.iloc[1:4]

# %%
census_dataFrame
# Out:
#                                                 Fact Fact Note    Alabama  \
# 1  Population estimates base, April 1, 2010,  (V2...       NaN  47,80,131
# 2  Population, percent change - April 1, 2010 (es...       NaN      0.017
# 3                  Population, Census, April 1, 2010       NaN  47,79,736
#
#      Alaska    Arizona   Arkansas   California   Colorado Connecticut  \
# 1  7,10,249  63,92,301  29,16,025  3,72,54,522  50,29,324   35,74,114
# 2     0.045      0.084      0.025        0.054      0.102       0.001
# 3  7,10,231  63,92,017  29,15,918  3,72,53,956  50,29,196   35,74,097
#
#    Delaware  ... South Dakota    Tennessee        Texas       Utah   Vermont  \
# 1  8,97,936  ...   814195.000  6346298.000  2,51,46,100  27,63,888  6,25,741
# 2      0.06  ...        0.063        0.048        0.108      0.104    -0.002
# 3  8,97,934  ...   814180.000  6346105.000  2,51,45,561  27,63,885  6,25,741
#
#     Virginia Washington West Virginia  Wisconsin   Wyoming
# ...

# %%
#renaming the index
census_dataFrame.reset_index(drop=True,inplace=True)

# %%
census_dataFrame
# Out:
#                                                 Fact Fact Note    Alabama  \
# 0  Population estimates base, April 1, 2010,  (V2...       NaN  47,80,131
# 1  Population, percent change - April 1, 2010 (es...       NaN      0.017
# 2                  Population, Census, April 1, 2010       NaN  47,79,736
#
#      Alaska    Arizona   Arkansas   California   Colorado Connecticut  \
# 0  7,10,249  63,92,301  29,16,025  3,72,54,522  50,29,324   35,74,114
# 1     0.045      0.084      0.025        0.054      0.102       0.001
# 2  7,10,231  63,92,017  29,15,918  3,72,53,956  50,29,196   35,74,097
#
#    Delaware  ... South Dakota    Tennessee        Texas       Utah   Vermont  \
# 0  8,97,936  ...   814195.000  6346298.000  2,51,46,100  27,63,888  6,25,741
# 1      0.06  ...        0.063        0.048        0.108      0.104    -0.002
# 2  8,97,934  ...   814180.000  6346105.000  2,51,45,561  27,63,885  6,25,741
#
#     Virginia Washington West Virginia  Wisconsin   Wyoming
# ...

# %%
#renaming the records in fact column
census_dataFrame.insert(loc=1,column='year',value=['estimate_base','population_2016','population_2010'])

# %%
census_dataFrame
# Out:
#                                                 Fact             year  \
# 0  Population estimates base, April 1, 2010,  (V2...    estimate_base
# 1  Population, percent change - April 1, 2010 (es...  population_2016
# 2                  Population, Census, April 1, 2010  population_2010
#
#   Fact Note    Alabama    Alaska    Arizona   Arkansas   California  \
# 0       NaN  47,80,131  7,10,249  63,92,301  29,16,025  3,72,54,522
# 1       NaN      0.017     0.045      0.084      0.025        0.054
# 2       NaN  47,79,736  7,10,231  63,92,017  29,15,918  3,72,53,956
#
#     Colorado Connecticut  ... South Dakota    Tennessee        Texas  \
# 0  50,29,324   35,74,114  ...   814195.000  6346298.000  2,51,46,100
# 1      0.102       0.001  ...        0.063        0.048        0.108
# 2  50,29,196   35,74,097  ...   814180.000  6346105.000  2,51,45,561
#
#         Utah   Vermont   Virginia Washington West Virginia  Wisconsin  \
# ...

# %%
census_dataFrame.drop(labels='Fact',axis=1,inplace=True)

# %%
census_dataFrame.head()
# Out:
#               year Fact Note    Alabama    Alaska    Arizona   Arkansas  \
# 0    estimate_base       NaN  47,80,131  7,10,249  63,92,301  29,16,025
# 1  population_2016       NaN      0.017     0.045      0.084      0.025
# 2  population_2010       NaN  47,79,736  7,10,231  63,92,017  29,15,918
#
#     California   Colorado Connecticut  Delaware  ... South Dakota  \
# 0  3,72,54,522  50,29,324   35,74,114  8,97,936  ...   814195.000
# 1        0.054      0.102       0.001      0.06  ...        0.063
# 2  3,72,53,956  50,29,196   35,74,097  8,97,934  ...   814180.000
#
#      Tennessee        Texas       Utah   Vermont   Virginia Washington  \
# 0  6346298.000  2,51,46,100  27,63,888  6,25,741  80,01,041  67,24,545
# 1        0.048        0.108      0.104    -0.002      0.051      0.084
# 2  6346105.000  2,51,45,561  27,63,885  6,25,741  80,01,024  67,24,540
#
#   West Virginia  Wisconsin   Wyoming
# 0     18,53,011  56,87,289  5,63,767
# 1        -0.012      0.016     0.039
# ...

# %%
#dropping NaN columns
census_dataFrame.dropna(axis=1,inplace=True)

# %%
census_dataFrame.head()
# Out:
#               year    Alabama    Alaska    Arizona   Arkansas   California  \
# 0    estimate_base  47,80,131  7,10,249  63,92,301  29,16,025  3,72,54,522
# 1  population_2016      0.017     0.045      0.084      0.025        0.054
# 2  population_2010  47,79,736  7,10,231  63,92,017  29,15,918  3,72,53,956
#
#     Colorado Connecticut  Delaware      Florida  ... South Dakota  \
# 0  50,29,324   35,74,114  8,97,936  1,88,04,592  ...   814195.000
# 1      0.102       0.001      0.06        0.096  ...        0.063
# 2  50,29,196   35,74,097  8,97,934  1,88,01,310  ...   814180.000
#
#      Tennessee        Texas       Utah   Vermont   Virginia Washington  \
# 0  6346298.000  2,51,46,100  27,63,888  6,25,741  80,01,041  67,24,545
# 1        0.048        0.108      0.104    -0.002      0.051      0.084
# 2  6346105.000  2,51,45,561  27,63,885  6,25,741  80,01,024  67,24,540
#
#   West Virginia  Wisconsin   Wyoming
# 0     18,53,011  56,87,289  5,63,767
# ...

# %%
census_dataFrame.isna().any()
# Out:
# year              False
# Alabama           False
# Alaska            False
# Arizona           False
# Arkansas          False
# California        False
# Colorado          False
# Connecticut       False
# Delaware          False
# Florida           False
# Georgia           False
# Hawaii            False
# Idaho             False
# Illinois          False
# Indiana           False
# Iowa              False
# Kansas            False
# Kentucky          False
# Louisiana         False
# Maine             False
# Maryland          False
# Massachusetts     False
# Michigan          False
# Minnesota         False
# Mississippi       False
# Missouri          False
# Montana           False
# Nebraska          False
# Nevada            False
# New Hampshire     False
# New Jersey        False
# New Mexico        False
# New York          False
# North Carolina    False
# North Dakota      False
# Ohio              False
# Oklahoma          False
# Oregon            False
# ...

# %%
census_dataFrame.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
census_dataFrame.dtypes
# Out:
# year               object
# Alabama            object
# Alaska             object
# Arizona            object
# Arkansas           object
# California         object
# Colorado           object
# Connecticut        object
# Delaware           object
# Florida            object
# Georgia            object
# Hawaii             object
# Idaho              object
# Illinois           object
# Indiana            object
# Iowa               object
# Kansas             object
# Kentucky           object
# Louisiana          object
# Maine              object
# Maryland           object
# Massachusetts      object
# Michigan           object
# Minnesota          object
# Mississippi        object
# Missouri           object
# Montana            object
# Nebraska           object
# Nevada             object
# New Hampshire      object
# New Jersey         object
# New Mexico        float64
# New York          float64
# North Carolina    float64
# North Dakota      float64
# ...

# %%
#taking transpose to match the gun dataset
census_dataFrame = census_dataFrame.T

# %%
census_dataFrame.head(3)
# Out:
#                      0                1                2
# year     estimate_base  population_2016  population_2010
# Alabama      47,80,131            0.017        47,79,736
# Alaska        7,10,249            0.045         7,10,231

# %%
census_dataFrame.columns=['estimate_base','population percent','population 2010']

# %%
census_dataFrame.drop(labels='year',axis=0,inplace=True)

# %%
census_dataFrame['population 2010'] = census_dataFrame['population 2010'].astype(str)
census_dataFrame['population 2010']
# Out:
# Alabama             47,79,736
# Alaska               7,10,231
# Arizona             63,92,017
# Arkansas            29,15,918
# California        3,72,53,956
# Colorado            50,29,196
# Connecticut         35,74,097
# Delaware             8,97,934
# Florida           1,88,01,310
# Georgia             96,87,653
# Hawaii              13,60,301
# Idaho               15,67,582
# Illinois          1,28,30,632
# Indiana             64,83,802
# Iowa                30,46,355
# Kansas              28,53,118
# Kentucky            43,39,367
# Louisiana           45,33,372
# Maine               13,28,361
# Maryland            57,73,552
# Massachusetts       65,47,629
# Michigan            98,83,640
# Minnesota           53,03,925
# Mississippi         29,67,297
# Missouri            59,88,927
# Montana              9,89,415
# Nebraska            18,26,341
# Nevada              27,00,551
# New Hampshire       13,16,470
# New Jersey          87,91,894
# New Mexico          2059179.0
# ...

# %%
census_dataFrame['population 2010'] = census_dataFrame['population 2010'].str.replace(",","")

# %%
census_dataFrame['population 2010'] = census_dataFrame['population 2010'].astype(float)

# %%
census_dataFrame['population percent'] = census_dataFrame['population percent'].astype(float)

# %%
census_dataFrame['population percent'] = census_dataFrame['population percent'].apply(lambda x:x+1)

# %%
census_dataFrame['estimate_base'] = census_dataFrame['estimate_base'].astype(str)

# %%
census_dataFrame['estimate_base'] = census_dataFrame['estimate_base'].str.replace(",","")

# %%
census_dataFrame['estimate_base'] = census_dataFrame['estimate_base'].astype(float)

# %%
population_2016 = census_dataFrame['estimate_base']*census_dataFrame['population percent']

# %%
census_dataFrame['population_2016'] = population_2016.astype(int)

# %%
#starting gun dataset
month_value = gun_dataFrame['month'].str.split("-").str[1]
year_value = gun_dataFrame['month'].str.split("-").str[0]

# %%
gun_dataFrame.insert(loc=1,column='year',value=year_value)

# %%
gun_dataFrame.insert(loc=2,column='months',value=month_value)

# %%
gun_dataFrame.head()
# Out:
#      month  year months       state   permit  permit_recheck  handgun  \
# 0  2017-09  2017     09     Alabama  16717.0             0.0   5734.0
# 1  2017-09  2017     09      Alaska    209.0             2.0   2320.0
# 2  2017-09  2017     09     Arizona   5069.0           382.0  11063.0
# 3  2017-09  2017     09    Arkansas   2935.0           632.0   4347.0
# 4  2017-09  2017     09  California  57839.0             0.0  37165.0
#
#    long_gun   other  multiple  ...  returned_other  rentals_handgun  \
# 0    6320.0   221.0       317  ...             0.0              0.0
# 1    2930.0   219.0       160  ...             0.0              0.0
# 2    7946.0   920.0       631  ...             0.0              0.0
# 3    6063.0   165.0       366  ...             0.0              0.0
# 4   24581.0  2984.0         0  ...             0.0              0.0
#
#    rentals_long_gun  private_sale_handgun  private_sale_long_gun  \
# 0               0.0                   9.0                   16.0
# ...

# %%
gun_dataFrame['months'] = gun_dataFrame['months'].astype(int)

# %%
gun_dataFrame['months'] = gun_dataFrame['months'].apply(lambda x: calendar.month_abbr[x])

# %%
gun_dataFrame.head()
# Out:
#      month  year months       state   permit  permit_recheck  handgun  \
# 0  2017-09  2017    Sep     Alabama  16717.0             0.0   5734.0
# 1  2017-09  2017    Sep      Alaska    209.0             2.0   2320.0
# 2  2017-09  2017    Sep     Arizona   5069.0           382.0  11063.0
# 3  2017-09  2017    Sep    Arkansas   2935.0           632.0   4347.0
# 4  2017-09  2017    Sep  California  57839.0             0.0  37165.0
#
#    long_gun   other  multiple  ...  returned_other  rentals_handgun  \
# 0    6320.0   221.0       317  ...             0.0              0.0
# 1    2930.0   219.0       160  ...             0.0              0.0
# 2    7946.0   920.0       631  ...             0.0              0.0
# 3    6063.0   165.0       366  ...             0.0              0.0
# 4   24581.0  2984.0         0  ...             0.0              0.0
#
#    rentals_long_gun  private_sale_handgun  private_sale_long_gun  \
# 0               0.0                   9.0                   16.0
# ...

# %%
gun_dataFrame.fillna(0,inplace=True)

# %%
census_dataFrame.head(5)
# Out:
#             estimate_base  population percent  population 2010  \
# Alabama         4780131.0               1.017        4779736.0
# Alaska           710249.0               1.045         710231.0
# Arizona         6392301.0               1.084        6392017.0
# Arkansas        2916025.0               1.025        2915918.0
# California     37254522.0               1.054       37253956.0
#
#             population_2016
# Alabama             4861393
# Alaska               742210
# Arizona             6929254
# Arkansas            2988925
# California         39266266

# %%
temp_dataFrame = gun_dataFrame[(gun_dataFrame['state']=='California') & (gun_dataFrame['year']=='2017')]

# %%
temp_dataFrame
# Out:
#        month  year months       state   permit  permit_recheck  handgun  \
# 4    2017-09  2017    Sep  California  57839.0             0.0  37165.0
# 59   2017-08  2017    Aug  California  59528.0             0.0  41110.0
# 114  2017-07  2017    Jul  California  52610.0             0.0  37027.0
# 169  2017-06  2017    Jun  California  60142.0             0.0  42726.0
# 224  2017-05  2017    May  California  58722.0             0.0  42442.0
# 279  2017-04  2017    Apr  California  58147.0             0.0  45182.0
# 334  2017-03  2017    Mar  California  65892.0             0.0  48732.0
# 389  2017-02  2017    Feb  California  56533.0             0.0  44363.0
# 444  2017-01  2017    Jan  California  62397.0             0.0  41516.0
#
#      long_gun   other  multiple  ...  returned_other  rentals_handgun  \
# 4     24581.0  2984.0         0  ...             0.0              0.0
# 59    26220.0  3058.0         0  ...             0.0              0.0
# ...

# %%
plt.plot(temp_dataFrame['months'],temp_dataFrame['permit'])

# %%
temp_dataFrame.sort_values(by='months',ascending=False)
# Out:
#        month  year months       state   permit  permit_recheck  handgun  \
# 4    2017-09  2017    Sep  California  57839.0             0.0  37165.0
# 224  2017-05  2017    May  California  58722.0             0.0  42442.0
# 334  2017-03  2017    Mar  California  65892.0             0.0  48732.0
# 169  2017-06  2017    Jun  California  60142.0             0.0  42726.0
# 114  2017-07  2017    Jul  California  52610.0             0.0  37027.0
# 444  2017-01  2017    Jan  California  62397.0             0.0  41516.0
# 389  2017-02  2017    Feb  California  56533.0             0.0  44363.0
# 59   2017-08  2017    Aug  California  59528.0             0.0  41110.0
# 279  2017-04  2017    Apr  California  58147.0             0.0  45182.0
#
#      long_gun   other  multiple  ...  returned_other  rentals_handgun  \
# 4     24581.0  2984.0         0  ...             0.0              0.0
# 224   24495.0  2760.0         0  ...             0.0              0.0
# ...
